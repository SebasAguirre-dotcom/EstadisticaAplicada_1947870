# %% [markdown]
# ## Estadistica Aplicada
# Sesión 6 - 21 agosto
#
# Jorge Sebastian Aguirre Jimenez 1947870
#
# G41

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nacimientos=pd.DataFrame({'Municipio':['Monterrey','Apodaca','Escobedo','Santiago'],'Bebes_nacidos':[233,569,780,123],'Muertos':[123,80,23,12]})

# %%
nacimientos
# Out:
#    Municipio  Bebes_nacidos  Muertos
# 0  Monterrey            233      123
# 1    Apodaca            569       80
# 2   Escobedo            780       23
# 3   Santiago            123       12

# %%
nacimientos=nacimientos.sort_values('Bebes_nacidos',ascending=False)

# %%
plt.bar(nacimientos['Municipio'],nacimientos['Bebes_nacidos'],color=['black'])
plt.title('Nacimientos en NL en 2020')
plt.xlabel('Municipios')
plt.ylabel('Cantidad de bebes nacidos')
plt.show()

# %%
personas=['Juan','Pedro','Ana','Ale']
edades=[23,18,20,31]

# %%
plt.bar(personas,edades)
plt.show()

# %%
#Lienzo
fig,(panel1,panel2)=plt.subplots(2,1)
fig.tight_layout()

#grafica1 nacimientos
x1=nacimientos['Municipio']
y1=nacimientos['Bebes_nacidos']
panel1.bar(x1,y1)

x2=personas
y2=edades
panel2.bar(x2,y2)
plt.show()

# %% [markdown]
# ## Graficar con pandas

# %% [markdown]
# #vamos a graficar con pandas
# dataframe['columns'].plot.tipo()

# %%
nacimientos.plot.bar()
plt.title('')
plt.show()

# %%
#Barras apiladas
nacimientos.plot.bar(stacked=True);

# %%
nacimientos.plot.area()
# Out:
# <Axes: >

# %%
nacimientos.plot.line();

# %%
nacimientos['Bebes_nacidos'].plot.hist()
plt.show()
