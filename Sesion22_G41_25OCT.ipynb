# %% [markdown]
# # Estadistica Aplicada
# ## Jorge Sebastian Aguirre Jimenez 1947870
# ## 25 de octubre

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_predict
## estimar modelo ARIMA
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm

# %%
desempleo_mex=pd.read_excel('desempleo_mex.xlsx')

# %%
desempleo_mex.head()
# Out:
#      meses  tasa de desempleo
# 0  2005/01           3.951998
# 1  2005/02           3.773302
# 2  2005/03           3.627075
# 3  2005/04           3.363412
# 4  2005/05           3.303693

# %%
desempleo_mex.dtypes
# Out:
# meses                 object
# tasa de desempleo    float64
# dtype: object

# %%
desempleo_mex.isnull().sum()
# Out:
# meses                0
# tasa de desempleo    0
# dtype: int64

# %%
## convertir en tiempo
desempleo_mex['meses']=pd.to_datetime(desempleo_mex['meses'],format='%Y/%m')

# %%
desempleo_mex
# Out:
#          meses  tasa de desempleo
# 0   2005-01-01           3.951998
# 1   2005-02-01           3.773302
# 2   2005-03-01           3.627075
# 3   2005-04-01           3.363412
# 4   2005-05-01           3.303693
# ..         ...                ...
# 219 2023-04-01           2.822799
# 220 2023-05-01           2.931125
# 221 2023-06-01           2.652033
# 222 2023-07-01           3.129870
# 223 2023-08-01           2.955346
#
# [224 rows x 2 columns]

# %%
desempleo_mex=desempleo_mex.set_index('meses')
desempleo_mex=desempleo_mex.asfreq('MS')

# %%
desempleo_mex.index
# Out:
# DatetimeIndex(['2005-01-01', '2005-02-01', '2005-03-01', '2005-04-01',
#                '2005-05-01', '2005-06-01', '2005-07-01', '2005-08-01',
#                '2005-09-01', '2005-10-01',
#                ...
#                '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01',
#                '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01',
#                '2023-07-01', '2023-08-01'],
#               dtype='datetime64[ns]', name='meses', length=224, freq='MS')

# %%
desempleo_mex['tasa de desempleo'].plot(figsize=(10,6))
plt.xlabel('mes')
plt.ylabel('%')
plt.title('Tasa de desempleo en Mexico 2005-2023')
# Out:
# Text(0.5, 1.0, 'Tasa de desempleo en Mexico 2005-2023')

# %%
## Prueba dickey-fuller
prueba_adf=adfuller(desempleo_mex['tasa de desempleo'])
pvalue=prueba_adf[1]
pvalue.round(2)
# Out:
# 0.25

# %% [markdown]
# No rechazamos H0, significa que la tasa de desempleo es un proceso no estacionario

# %%
## 1ras diferencias
desempleo_mex['desempleo_diff']=desempleo_mex['tasa de desempleo'].diff()

# %%
desempleo_mex['desempleo_diff'].plot()
# Out:
# <Axes: xlabel='meses'>

# %%
prueba_adf1=adfuller(desempleo_mex['desempleo_diff'].dropna())
pvalue1=prueba_adf1[1]
pvalue1.round(2)
# Out:
# 0.01

# %% [markdown]
# Rechazamos H0, las primeras diferencias son un proceso estacionario

# %%
ig, ax=plt.subplots(1,2,figsize=(10,4))
plot_acf(desempleo_mex['desempleo_diff'].dropna(),zero=False, lags=30, ax=ax[0])
plot_pacf(desempleo_mex['desempleo_diff'].dropna(),zero=False, lags=40, ax=ax[1])
plt.show()

# %% [markdown]
# El desempleo es una serie con componente estacional

# %%
## determinar el orden del SARIMA
pm.auto_arima(desempleo_mex['tasa de desempleo'], start_p=1, max_p=7, start_q=1,max_q=7, ic='aic', m=12,seasonal=True, start_P=1, start_Q=1, max_P=7, max_Q=7)
# Out:
# ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# El desempleo es una SARIMA (1,1,0)(1,0,1,12)

# %%
#plt.rcParams['figure.figsize']=(14,4)
#plot_acf(desempleo_mex['desempleo_diff'].dropna(),zero=False, lags=30)

# %%
model=ARIMA(desempleo_mex['tasa de desempleo'], order=(1,1,0), seasonal_order=(1,0,1,12))
results=model.fit()
print(results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                  tasa de desempleo   No. Observations:                  224
# Model:             ARIMA(1, 1, 0)x(1, 0, [1], 12)   Log Likelihood                 -28.306
# Date:                            Thu, 26 Oct 2023   AIC                             64.613
# Time:                                    14:24:00   BIC                             78.241
# Sample:                                01-01-2005   HQIC                            70.115
#                                      - 08-01-2023
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3689      0.061     -6.075      0.000      -0.488      -0.250
# ar.S.L12       0.9763      0.014     70.965      0.000       0.949       1.003
# ...

# %%
desempleo_mex.tail()
# Out:
#             tasa de desempleo  desempleo_diff
# meses
# 2023-04-01           2.822799        0.430258
# 2023-05-01           2.931125        0.108327
# 2023-06-01           2.652033       -0.279093
# 2023-07-01           3.129870        0.477837
# 2023-08-01           2.955346       -0.174524

# %%
# Pronostico
plot_predict(results, '2023-09-01','2024-02-01')
desempleo_mex['tasa de desempleo'].plot()
plt.title('Desempleo en Mexico')
# Out:
# Text(0.5, 1.0, 'Desempleo en Mexico')

# %%
results.predict('2023-09-01','2024-02-01')
# Out:
# 2023-09-01    2.951735
# 2023-10-01    2.750669
# 2023-11-01    2.483561
# 2023-12-01    2.262441
# 2024-01-01    2.661989
# 2024-02-01    2.481788
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
forecast=results.get_forecast(steps=6)
forecast_mean=forecast.predicted_mean
forecast_ci=forecast.conf_int()

# %%
inicio='2023-09-01'
fin='2024-02-01'

# %%
pronostico_valor=forecast_mean[inicio:fin]
pronostico_intervalos=forecast_ci.loc[inicio:fin]

# %%
df_pronostico=pd.DataFrame({'pronostico': pronostico_valor, 'limite inferior':pronostico_intervalos.iloc[:,0],'limite superior':pronostico_intervalos.iloc[:,1]})
df_pronostico
# Out:
#             pronostico  limite inferior  limite superior
# 2023-09-01    2.951735         2.431389         3.472082
# 2023-10-01    2.750669         2.135374         3.365963
# 2023-11-01    2.483561         1.750114         3.217009
# 2023-12-01    2.262441         1.439566         3.085317
# 2024-01-01    2.661989         1.754471         3.569507
# 2024-02-01    2.481788         1.498252         3.465324

# %%
print(f'La tasa de desempleo pronosticada para septiembre 2023 es {df_pronostico.iloc[0,0].round(2)}% pero puede estar entre {df_pronostico.iloc[0,1].round(2)}% y {df_pronostico.iloc[0,2].round(2)}%')
# Out:
# La tasa de desempleo pronosticada para septiembre 2023 es 2.95% pero puede estar entre 2.43% y 3.47%
