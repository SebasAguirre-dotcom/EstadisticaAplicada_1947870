# %% [markdown]
# # Estadistica Aplicada
# ## Jorge Sebastian Aguirre Jimenez 1947870
# ## 19 de octubre

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (3.0.4)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.11.2)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (2.0.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python311\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\appdata\roaming\python\python311\site-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python311\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_predict
import pmdarima as pm

# %%
plt.rcParams['figure.figsize']=(10,6)

# %%
df_amazon=pd.read_excel('amazon (1).xlsx')

# %%
df_amazon=df_amazon.set_index('fecha')
df_amazon=df_amazon.asfreq('B')

# %%
df_amazon.isnull().sum()
# Out:
# amazon    47
# dtype: int64

# %%
df_amazon['amazon']=df_amazon['amazon'].fillna(method='pad')

# %%
df_amazon['amazon'].plot()
plt.xlim('2015-01-01','2015-12-31');

# %%
df_amazon.tail(1)
# Out:
#                amazon
# fecha
# 2019-12-30  51.478008

# %%
#conservamos todas las obs menos la última
ult_obs=df_amazon.loc['2019-12-30']
#vamos a pronosticar la ultima observación y vamos a ver que tan cerca o lejos queda nuestro pronostico

# %%
# Prueba de dickey fuller aumentada
prueba_dfa=adfuller(df_amazon['amazon'])
pvalues=prueba_dfa[1]
pvalues.round(2)
# Out:
# 0.51

# %% [markdown]
# No rechazamos H0, el precio de las accion de amazon son " no estacionaria "

# %%
df_amazon['amazon_diff']=df_amazon['amazon'].diff()

# %%
df_amazon['amazon_diff'].plot()
# Out:
# <Axes: xlabel='fecha'>

# %%
## prueba dickey fuller aumentada
prueba_dfa1=adfuller(df_amazon['amazon_diff'].dropna())
pvalue1=prueba_dfa1[1]
pvalue1.round(2)
# Out:
# 0.0

# %% [markdown]
# Rechazamos H0, significa que las primeras diferencias de la acción de amazon son un proceso estacionario

# %%
ig,ax=plt.subplots(1,2,figsize=(10,4))
plot_acf(df_amazon['amazon_diff'].dropna(),zero=False,lags=30,ax=ax[0])
plot_pacf(df_amazon['amazon'].dropna(),zero=False,lags=30,ax=ax[1])
plt.show()

# %%
# vamos a estimar varios modelos y que se guarde el AIC BIC
ic = {}
for ar in range(7):
    for ma in range(7):
        print(f"AR: {ar}, MA: {ma}")
        modelo = ARIMA(df_amazon['amazon_diff'].dropna(), order=(ar, 0, ma))
        resultado = modelo.fit()
        ic[(ar, ma)] = [resultado.aic, resultado.bic]
 
ic = pd.DataFrame(ic, index=["AIC", "BIC"]).T
ic.index = ic.index.set_names(["AR", "MA"])
# Out:
# AR: 0, MA: 0
# AR: 0, MA: 1
# AR: 0, MA: 2
# AR: 0, MA: 3
# AR: 0, MA: 4
# AR: 0, MA: 5
# AR: 0, MA: 6
# AR: 1, MA: 0
# AR: 1, MA: 1
# AR: 1, MA: 2
# AR: 1, MA: 3
# AR: 1, MA: 4
# AR: 1, MA: 5
# AR: 1, MA: 6
# AR: 2, MA: 0
# AR: 2, MA: 1
# AR: 2, MA: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 2, MA: 3
# AR: 2, MA: 4
# AR: 2, MA: 5
# AR: 2, MA: 6
# AR: 3, MA: 0
# AR: 3, MA: 1
# AR: 3, MA: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 3, MA: 3
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 3, MA: 4
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 3, MA: 5
# AR: 3, MA: 6
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 4, MA: 0
# AR: 4, MA: 1
# AR: 4, MA: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 4, MA: 3
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 4, MA: 4
# AR: 4, MA: 5
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 4, MA: 6
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 5, MA: 0
# AR: 5, MA: 1
# AR: 5, MA: 2
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 5, MA: 3
# AR: 5, MA: 4
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 5, MA: 5
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 5, MA: 6
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 6, MA: 0
# AR: 6, MA: 1
# AR: 6, MA: 2
# AR: 6, MA: 3
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 6, MA: 4
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AR: 6, MA: 5
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# AR: 6, MA: 6
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
ic.sort_values('BIC').head(1)
# Out:
#                AIC         BIC
# AR MA
# 1  1   2376.968527  2397.65208

# %% [markdown]
# * amazon_diff es un ARMA (1,1)=ARIMA(1,0,1)
# * amazon ARIMA (1,1,1)

# %%
## 1ras diferencias amazon
pm.auto_arima(df_amazon['amazon_diff'].dropna(),start_p=1, max_p=7, start_q=1, max_q=7, ic='bic',seasonal=False)
# Out:
# ARIMA(order=(2, 0, 2), scoring_args={}, suppress_warnings=True)

# %%
## amazon
pm.auto_arima(df_amazon['amazon'], start_p=1, max_p=7, start_q=1, max_q=7, seasonal=False)
# Out:
# ARIMA(order=(2, 1, 2), scoring_args={}, suppress_warnings=True)

# %%
# estimar el modelo
model= ARIMA(df_amazon['amazon'], order=(1,1,1))
results=model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 amazon   No. Observations:                 1302
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1186.528
# Date:                Mon, 23 Oct 2023   AIC                           2379.056
# Time:                        14:46:08   BIC                           2394.569
# Sample:                    01-02-2015   HQIC                          2384.876
#                          - 12-30-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7517      0.071     10.587      0.000       0.613       0.891
# ma.L1         -0.8391      0.058    -14.410      0.000      -0.953      -0.725
# sigma2         0.3628      0.008     43.511      0.000       0.346       0.379
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):               964.80
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.34   Skew:                            -0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df_amazon.tail(1)
# Out:
#                amazon  amazon_diff
# fecha
# 2019-12-30  51.478008    -1.387188

# %%
results.predict(start='2019-12-30', end='2020-01-05')
# Out:
# 2019-12-30    52.847078
# 2019-12-31    51.584019
# 2020-01-01    51.663710
# 2020-01-02    51.723617
# 2020-01-03    51.768651
# 2020-01-06    51.802505
# Freq: B, Name: predicted_mean, dtype: float64

# %% [markdown]
# Pronosticamos que el dia 30 de diciembre de 2019 el precio de la accion de amazon se encuentre en 52.84

# %%
plot_predict(results, start='2019-12-30', end='2020-01-05')
df_amazon['amazon'].plot()
plt.xlim('2019-08-01','2020-01-05')
plt.ylim(50,57)
# Out:
# (50.0, 57.0)
